# %% [markdown]
# # Piano Transcription

# %% [markdown]
# The goal of this homework is implementing ``onsets and frames'', a state-of-the-art piano transcription model.

# %% [markdown]
# ## Download the Dataset

# %% [markdown]
# We use a subset of the MAESTRO dataset that contains 170 performance pieces played by junior pianists. The audio files and their corresponding midi files are paired for each piece. We will convert the midi files into piano rolls and train our network to predict them from the audio in a supervised way. We randomly selected 100 / 20 / 50 (train / valid / test) performances from the original dataset for this homework.

# %%
# Download the audio files
# !gdown 1EQ6fFJRhAEugkkCwG2YvmXJyL7Q3Xhes
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1EQ6fFJRhAEugkkCwG2YvmXJyL7Q3Xhes
# From (redirected): https://drive.google.com/uc?id=1EQ6fFJRhAEugkkCwG2YvmXJyL7Q3Xhes&confirm=t&uuid=96693988-51b3-4a21-894f-4cbfd7733fbd
# To: /home/hongju/GCT634/hw3/gct634-maestro.zip
# 100%|██████████████████████████████████████| 1.14G/1.14G [01:48<00:00, 10.4MB/s]

# %%
# uncompress the audio files
# %%capture prevents the output log from displaying in this cell. If you want to see the log, remove %%capture below.
# %%capture

# !unzip gct634-maestro.zip
# Out:
# Archive:  gct634-maestro.zip
#    creating: gct634-maestro/
#   inflating: __MACOSX/._gct634-maestro
#    creating: gct634-maestro/2013/
#   inflating: __MACOSX/gct634-maestro/._2013
#    creating: gct634-maestro/2014/
#   inflating: __MACOSX/gct634-maestro/._2014
#    creating: gct634-maestro/2015/
#   inflating: __MACOSX/gct634-maestro/._2015
#   inflating: gct634-maestro/.DS_Store
#   inflating: __MACOSX/gct634-maestro/._.DS_Store
#    creating: gct634-maestro/2008/
#   inflating: __MACOSX/gct634-maestro/._2008
#    creating: gct634-maestro/2006/
#   inflating: __MACOSX/gct634-maestro/._2006
#    creating: gct634-maestro/2009/
#   inflating: __MACOSX/gct634-maestro/._2009
#    creating: gct634-maestro/2017/
#   inflating: __MACOSX/gct634-maestro/._2017
#   inflating: gct634-maestro/data.json
#   inflating: __MACOSX/gct634-maestro/._data.json
#    creating: gct634-maestro/2018/
#   inflating: __MACOSX/gct634-maestro/._2018
#    creating: gct634-maestro/2011/
#   inflating: __MACOSX/gct634-maestro/._2011
#    creating: gct634-maestro/.ipynb_checkpoints/
#   inflating: __MACOSX/gct634-maestro/._.ipynb_checkpoints
#    creating: gct634-maestro/2004/
#   inflating: __MACOSX/gct634-maestro/._2004
#   inflating: gct634-maestro/2013/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1.flac
#   inflating: __MACOSX/gct634-maestro/2013/._ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1.flac
#   inflating: gct634-maestro/2013/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_18_R3_2013_wav--2.midi
#   inflating: __MACOSX/gct634-maestro/2013/._ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_18_R3_2013_wav--2.midi
#   inflating: gct634-maestro/2013/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--4.midi
#   inflating: __MACOSX/gct634-maestro/2013/._ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--4.midi
#   inflating: gct634-maestro/2013/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_14_R2_2013_wav--4.midi
#   inflating: __MACOSX/gct634-maestro/2013/._ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_14_R2_2013_wav--4.midi
#   inflating: gct634-maestro/2013/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--4.flac
#   inflating: __MACOSX/gct634-maestro/2013/._ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--4.flac
#   inflating: gct634-maestro/2013/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--3.midi
#   inflating: __MACOSX/gct634-maestro/2013/._ORIG-MIDI_03_7_8_13_Group__MID--AUDIO
IDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.flac
#   inflating: gct634-maestro/2004/MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.flac
#   inflating: __MACOSX/gct634-maestro/2004/._MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.flac
#   inflating: gct634-maestro/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.midi
#   inflating: __MACOSX/gct634-maestro/2004/._MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.midi
#   inflating: gct634-maestro/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.midi
#   inflating: __MACOSX/gct634-maestro/2004/._MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.midi

# %% [markdown]
# Once you unzip the file, you will see the following folders in the ``gct634-maestro'' folder.
#
# ```
# 2004  2006  2008  2009  2011  2013  2014  2015  2017  2018  data.json
# ```

# %% [markdown]
# ## Check the Audio and MIDI Files
#
# Install python packages to handle audio and MIDI

# %%
# %%capture prevents the output log from displaying in this cell. If you want to see the log, remove %%capture below.
# %%capture

# !apt-get install -y fluidsynth
# !pip install pyfluidsynth
# !pip install --upgrade pyfluidsynth
# !pip install pretty_midi
# !pip install mir_eval
# !pip install libfmp
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# Requirement already satisfied: pyfluidsynth in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: numpy in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pyfluidsynth) (1.26.4)
# Requirement already satisfied: pyfluidsynth in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: numpy in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pyfluidsynth) (1.26.4)
# Requirement already satisfied: pretty_midi in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pretty_midi) (1.26.4)
# Requirement already satisfied: mido>=1.1.16 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pretty_midi) (1.3.3)
# Requirement already satisfied: six in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: packaging in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from mido>=1.1.16->pretty_midi) (24.2)
# Requirement already satisfied: mir_eval in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (0.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from mir_eval) (1.26.4)
# Requirement already satisfied: scipy>=1.4.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from mir_eval) (1.13.1)
# Requirement already satisfied: decorator in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from mir_eval) (5.2.1)
# Requirement already satisfied: libfmp in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (1.2.6)
# Requirement already satisfied: ipython<8.0.0,>=7.10.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (7.34.0)
# Requirement already satisfied: librosa<1.0.0,>=0.8.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (0.10.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (3.7.3)
# Requirement already satisfied: music21<6.0.0,>=5.7.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (5.7.2)
# Requirement already satisfied: numba<1.0.0,>=0.56.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (0.60.0)
# Requirement already satisfied: numpy<2.0.0,>=1.19.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.1.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (2.2.3)
# Requirement already satisfied: pretty-midi<1.0.0,>=0.2.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (0.2.10)
# Requirement already satisfied: soundfile<1.0.0,>=0.9.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (0.13.1)
# Requirement already satisfied: scipy<2.0.0,>=1.5.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from libfmp) (1.13.1)
# Requirement already satisfied: setuptools>=18.5 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (75.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (0.19.2)
# Requirement already satisfied: decorator in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (5.2.1)
# Requirement already satisfied: pickleshare in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (5.14.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (3.0.50)
# Requirement already satisfied: pygments in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (2.19.1)
# Requirement already satisfied: backcall in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from ipython<8.0.0,>=7.10.0->libfmp) (4.9.0)
# Requirement already satisfied: audioread>=2.1.9 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (1.4.2)
# Requirement already satisfied: pooch>=1.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from librosa<1.0.0,>=0.8.0->libfmp) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.0->libfmp) (6.5.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from numba<1.0.0,>=0.56.0->libfmp) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pandas<3.0.0,>=1.1.0->libfmp) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pandas<3.0.0,>=1.1.0->libfmp) (2025.2)
# Requirement already satisfied: mido>=1.1.16 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pretty-midi<1.0.0,>=0.2.0->libfmp) (1.3.3)
# Requirement already satisfied: six in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pretty-midi<1.0.0,>=0.2.0->libfmp) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from soundfile<1.0.0,>=0.9.0->libfmp) (1.17.1)
# Requirement already satisfied: pycparser in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from cffi>=1.0->soundfile<1.0.0,>=0.9.0->libfmp) (2.22)
# Requirement already satisfied: zipp>=3.1.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib<4.0.0,>=3.3.0->libfmp) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0.0,>=7.10.0->libfmp) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0.0,>=7.10.0->libfmp) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pooch>=1.0->librosa<1.0.0,>=0.8.0->libfmp) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from pooch>=1.0->librosa<1.0.0,>=0.8.0->libfmp) (2.32.3)
# Requirement already satisfied: wcwidth in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.10.0->libfmp) (0.2.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa<1.0.0,>=0.8.0->libfmp) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<1.0.0,>=0.8.0->libfmp) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<1.0.0,>=0.8.0->libfmp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<1.0.0,>=0.8.0->libfmp) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hongju/anaconda3/envs/gct634/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<1.0.0,>=0.8.0->libfmp) (2025.1.31)

# %% [markdown]
# Let's load an example of the audio files.

# %%
import soundfile
import IPython.display as ipd

audio_file = 'gct634-maestro/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.flac'
audio, sr = soundfile.read(audio_file)
print(sr)
audio_seg = audio[:10*sr]

ipd.Audio(audio_seg, rate=sr)
# Out:
# 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Can you hear the beautiful piano music? Then, let's load the paired MIDI file

# %%
import libfmp.c1

midi_file = 'gct634-maestro/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.midi'
score = libfmp.c1.midi_to_list(midi_file)
libfmp.c1.visualize_piano_roll(score[:100], figsize=(8, 3))
# Out:
# (<Figure size 576x216 with 1 Axes>,
#  <Axes: xlabel='Time (seconds)', ylabel='Pitch'>)

# %% [markdown]
# Now, we synthesize MIDI file back to audio using Fluidsynth

# %%
import fluidsynth
import pretty_midi

pm = pretty_midi.PrettyMIDI(midi_file)
synth_audio = pm.fluidsynth(fs=sr)

synth_audio_seg = synth_audio[:10*sr]

ipd.Audio(synth_audio_seg, rate=sr)
# Out:
# fluidsynth: warning: SDL3 not initialized, SDL3 audio driver won't be usable. Have you called SDL_Init(SDL_INIT_AUDIO) ?
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The piano timbre will be different. But, it should sound pretty good.
#
# Now, we are going to build the onsets and frames model.

# %% [markdown]
# ## Dataloader
# This cell includes data loaders and mel-spectrogram setting. We are just going to use the functions.

# %%
# setup the basic data configuration
SAMPLE_RATE = 16000
MIN_MIDI = 21
MAX_MIDI = 108

HOP_SIZE = 512
N_MELS = 229
N_FFT = 2048
F_MIN = 30
F_MAX = 8000


from typing import Dict, List
from torch import Tensor
from numpy import ndarray
from numpy.random.mtrand import RandomState
from pretty_midi.pretty_midi import PrettyMIDI

import os
import json
import numpy as np
import torch
from torch.utils.data import Dataset
from tqdm import tqdm

def allocate_batch(batch:Dict[str,Tensor], device:torch.device) -> Dict[str,Tensor]:
    for key in batch.keys():
        if key != 'path':
            batch[key] = batch[key].to(device)
    return batch

class MAESTRO_small(Dataset):
    def __init__(self,
                 path:str = 'gct634-maestro',
                 groups:List[str] = None,
                 sequence_length:int = SAMPLE_RATE * 5,
                 hop_size:int = HOP_SIZE,
                 seed:int = 42,
                 random_sample:bool = True) -> None:
        self.path:str = path
        self.groups:list = groups if groups is not None else self.available_groups()
        assert all(group in self.available_groups() for group in self.groups)

        self.sample_length:int = ((sequence_length // hop_size) * hop_size) if sequence_length is not None else None
        self.random:RandomState = np.random.RandomState(seed)
        self.random_sample:bool = random_sample
        self.hop_size:int = hop_size

        self.data:List[Dict[str,Tensor]] = []

        print(f'Loading {len(groups)} group(s) of', self.__class__.__name__, 'at', path)
        for group in groups:
            file_list:List[tuple] = self.get_file_path_list_of_group(group)
            for input_files in tqdm(file_list, desc=f'Loading group {group}'):
                self.data.append(self.load(*input_files))

    @classmethod
    def available_groups(cls) -> List[str]:
        return ['train', 'validation', 'test', 'debug']

    def get_file_path_list_of_group(self, group:str) -> List[tuple]:
        metadata:List[dict] = json.load(open(os.path.join(self.path, 'data.json')))
        subset_name:str = 'train' if group == 'debug' else group

        files:List[tuple] = sorted([
                (os.path.join(self.path, row['audio_filename'].replace('.wav', '.flac')),
                 os.path.join(self.path, row['midi_filename']))
                for row in metadata if row['split'] == subset_name
            ])

        if group == 'debug':
            files = files[:10]
        else:
            files = [(audio if os.path.exists(audio) else audio.replace(
                '.flac', '.wav'), midi) for audio, midi in files]

        return files

    def load(self, audio_path:str, midi_path:str) -> Dict[str,Tensor]:
        """Loads an audio track and the corresponding labels."""
        audio, sr = soundfile.read(audio_path, dtype='int16')
        assert sr == SAMPLE_RATE

        frames_per_sec:float = sr / self.hop_size

        audio_tensor:Tensor = torch.ShortTensor(audio)
        audio_length:int = len(audio_tensor)

        midi:PrettyMIDI = pretty_midi.PrettyMIDI(midi_path)
        midi_length_sec:float = midi.get_end_time()
        frame_length:int = min(int(midi_length_sec * frames_per_sec), (audio_length // self.hop_size) + 1)

        audio_tensor = audio_tensor[:frame_length * self.hop_size]

        frame:ndarray = midi.get_piano_roll(fs=frames_per_sec)

        onset = np.zeros_like(frame)
        for inst in midi.instruments:
            for note in inst.notes:
                onset[note.pitch, int(note.start * frames_per_sec)] = 1

        # to shape (time, pitch (88))
        frame_tensor:Tensor = torch.from_numpy(frame[MIN_MIDI:MAX_MIDI + 1].T)
        onset_tensor:Tensor = torch.from_numpy(onset[MIN_MIDI:MAX_MIDI + 1].T)
        data = dict(path=audio_path, audio=audio_tensor, frame=frame_tensor, onset=onset_tensor)
        return data

    def __getitem__(self, index:int) -> Dict[str,Tensor]:
        data:Dict[str,Tensor] = self.data[index]

        audio:Tensor = data['audio']
        frames:Tensor = (data['frame'] >= 1)
        onsets:Tensor = (data['onset'] >= 1)

        frame_len:int = frames.shape[0]

        if self.sample_length is not None:
            n_steps:int = self.sample_length // self.hop_size

            step_begin:int = self.random.randint(frame_len - n_steps) if self.random_sample else 0
            step_end:int = step_begin + n_steps

            sample_begin:int = step_begin * self.hop_size
            sample_end:int = sample_begin + self.sample_length

            audio_seg:Tensor = audio[sample_begin:sample_end]
            frame_seg:Tensor = frames[step_begin:step_end]
            onset_seg:Tensor = onsets[step_begin:step_end]

            result = dict(path=data['path'])
            result['audio'] = audio_seg.float().div_(32768.0)
            result['frame'] = frame_seg.float()
            result['onset'] = onset_seg.float()
        else:
            result = dict(path=data['path'])
            result['audio'] = audio.float().div_(32768.0)
            result['frame'] = frames.float()
            result['onset'] = onsets.float()

        return result

    def __len__(self) -> int:
        return len(self.data)

# %% [markdown]
# ## Build the Model
#
# This cell includes neural network modules to build the onsets and frames model along with the mel-spectrogram. This is the main part that you are going to work on for this homework.

# %%
import random
import torch.nn as nn
import torchaudio.transforms as transforms

class LogMelSpectrogram(nn.Module):
    def __init__(self):
        super().__init__()
        self.melspectrogram = transforms.MelSpectrogram(
            sample_rate=SAMPLE_RATE,
            n_fft=N_FFT,
            hop_length=HOP_SIZE,
            f_min=F_MIN,
            f_max=F_MAX,
            n_mels=N_MELS,
            normalized=False)

    def forward(self, audio):
        # Alignment correction to match with piano roll.
        # When they convert the input into frames,
        # pretty_midi.get_piano_roll uses `ceil`,
        # but torchaudio.transforms.melspectrogram uses `round`.
        padded_audio = nn.functional.pad(audio, (HOP_SIZE // 2, 0), 'constant')
        mel = self.melspectrogram(padded_audio)[:, :, 1:]
        mel = mel.transpose(-1, -2)
        mel = torch.log(torch.clamp(mel, min=1e-9))
        return mel


class ConvStack(nn.Module):
    def __init__(self, n_mels, cnn_unit, fc_unit):
        super().__init__()

        # shape of input: (batch_size, 1 channel, frames, input_features)
        self.cnn = nn.Sequential(
            # layer 0
            nn.Conv2d(1, cnn_unit, (3, 3), padding=1),
            nn.BatchNorm2d(cnn_unit),
            nn.ReLU(),
            # layer 1
            nn.Conv2d(cnn_unit, cnn_unit, (3, 3), padding=1),
            nn.BatchNorm2d(cnn_unit),
            nn.ReLU(),
            # layer 2
            nn.MaxPool2d((1, 2)),
            nn.Dropout(0.25),
            nn.Conv2d(cnn_unit, cnn_unit * 2, (3, 3), padding=1),
            nn.BatchNorm2d(cnn_unit * 2),
            nn.ReLU(),
            # layer 3
            nn.MaxPool2d((1, 2)),
            nn.Dropout(0.25),
        )
        self.fc = nn.Sequential(
            nn.Linear((cnn_unit * 2) * (n_mels // 4), fc_unit),
            nn.Dropout(0.5))

    def forward(self, mel):
        x = mel.unsqueeze(1)
        x = self.cnn(x)
        x = x.transpose(1, 2).flatten(-2)
        x = self.fc(x)
        return x


class BiLSTM(nn.Module):
    inference_chunk_length = 512

    def __init__(self, input_features, recurrent_features):
        super().__init__()
        self.rnn = nn.LSTM(input_features, recurrent_features, batch_first=True, bidirectional=True)

    def forward(self, x):
        if self.training:
            return self.rnn(x)[0]
        else:
            # evaluation mode: support for longer sequences that do not fit in memory
            batch_size, sequence_length, input_features = x.shape
            hidden_size = self.rnn.hidden_size
            num_directions = 2 if self.rnn.bidirectional else 1

            h = torch.zeros(num_directions, batch_size, hidden_size, device=x.device)
            c = torch.zeros(num_directions, batch_size, hidden_size, device=x.device)
            output = torch.zeros(batch_size, sequence_length, num_directions * hidden_size, device=x.device)

            # forward direction
            slices = range(0, sequence_length, self.inference_chunk_length)
            for start in slices:
                end = start + self.inference_chunk_length
                output[:, start:end, :], (h, c) = self.rnn(x[:, start:end, :], (h, c))

            # reverse direction
            if self.rnn.bidirectional:
                h.zero_()
                c.zero_()

                for start in reversed(slices):
                    end = start + self.inference_chunk_length
                    result, (h, c) = self.rnn(x[:, start:end, :], (h, c))
                    output[:, start:end, hidden_size:] = result[:, :, hidden_size:]

            return output

class BasicOnsetsAndFrames(nn.Module):
    def __init__(self, cnn_unit, fc_unit):
        super().__init__()

        self.melspectrogram = LogMelSpectrogram()


        self.onset_stack = nn.Sequential(
            ConvStack(N_MELS, cnn_unit, fc_unit),
            nn.Linear(fc_unit, 88),
            nn.Sigmoid()
        )

        self.frame_stack = nn.Sequential(
            ConvStack(N_MELS, cnn_unit, fc_unit),
            nn.Linear(fc_unit, 88),
            nn.Sigmoid()
        )

    def forward(self, audio):
        mel = self.melspectrogram(audio)

        onset_pred = self.onset_stack(mel)  # (B, T, C)
        frame_pred = self.frame_stack(mel)  # (B, T, C)

        return frame_pred, onset_pred


class OnsetsAndFrames(nn.Module):
    def __init__(self, cnn_unit, fc_unit, rnn_unit):
        super().__init__()

        self.melspectrogram = LogMelSpectrogram()

        # onset
        self.onset_conv = ConvStack(N_MELS, cnn_unit, fc_unit)
        self.onset_bilstm = BiLSTM(fc_unit, rnn_unit)
        self.onset_fc = nn.Linear(rnn_unit * 2, 88)
        self.onset_sigmoid = nn.Sigmoid()

        # frame
        self.frame_stack = nn.Sequential(
            ConvStack(N_MELS, cnn_unit, fc_unit),
            nn.Linear(fc_unit, fc_unit),
            nn.Sigmoid()
        )
        self.frame_bilstm = BiLSTM(fc_unit, rnn_unit)
        self.frame_fc = nn.Linear(rnn_unit * 2, 88)
        self.frame_sigmoid = nn.Sigmoid()

    def forward(self, audio):

        mel = self.melspectrogram(audio)
        
        onset_feat = self.onset_conv(mel)
        onset_feat = self.onset_bilstm(onset_feat)
        onset_pred = self.onset_sigmoid(self.onset_fc(onset_feat))

        frame_feat = self.frame_stack(mel)
        combined_feat = torch.cat([frame_feat, onset_pred], dim=-1)

        frame_feat = self.frame_bilstm(combined_feat)
        frame_pred = self.frame_sigmoid(self.frame_fc(frame_feat))

        return frame_pred, onset_pred

# %%
print(sr)
# Out:
# 16000

# %% [markdown]
# ## Evaluation Functions
#
# This cell includes evaluation functions which compute frame-level and note-level accuracy metrics. ``extract_notes'' is used to infer MIDI notes from the onset and frame predictions.

# %%
import argparse
from datetime import datetime
from pathlib import Path
from collections import defaultdict

from torch.nn.utils import clip_grad_norm_
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader

from collections import defaultdict
from pathlib import Path

from mido import Message, MidiFile, MidiTrack
from mir_eval.transcription import precision_recall_f1_overlap as evaluate_notes
from mir_eval.util import hz_to_midi, midi_to_hz

def cycle(iterable):
    while True:
        for item in iterable:
            yield item

def evaluate(model, batch, device, save=False, save_path=None):
    metrics = defaultdict(list)
    batch = allocate_batch(batch, device)

    frame_pred, onset_pred = model(batch['audio'])

    criterion = nn.BCELoss()
    frame_loss = criterion(frame_pred, batch['frame'])
    onset_loss = criterion(onset_pred, batch['onset'])
    metrics['metric/loss/frame_loss'].append(frame_loss.cpu().numpy())
    metrics['metric/loss/onset_loss'].append(onset_loss.cpu().numpy())

    for batch_idx in range(batch['audio'].shape[0]):
        pr, re, f1 = framewise_eval(frame_pred[batch_idx], batch['frame'][batch_idx])
        metrics['metric/frame/frame_precision'].append(pr)
        metrics['metric/frame/frame_recall'].append(re)
        metrics['metric/frame/frame_f1'].append(f1)

        pr, re, f1 = framewise_eval(onset_pred[batch_idx], batch['onset'][batch_idx])
        metrics['metric/frame/onset_precision'].append(pr)
        metrics['metric/frame/onset_recall'].append(re)
        metrics['metric/frame/onset_f1'].append(f1)

        p_est, i_est = extract_notes(onset_pred[batch_idx], frame_pred[batch_idx])
        p_ref, i_ref = extract_notes(
            batch['onset'][batch_idx], batch['frame'][batch_idx])

        scaling = HOP_SIZE / SAMPLE_RATE

        i_ref = (i_ref * scaling).reshape(-1, 2)
        p_ref = np.array([midi_to_hz(MIN_MIDI + pitch) for pitch in p_ref])
        i_est = (i_est * scaling).reshape(-1, 2)
        p_est = np.array([midi_to_hz(MIN_MIDI + pitch) for pitch in p_est])

        p, r, f, o = evaluate_notes(
            i_ref, p_ref, i_est, p_est, offset_ratio=None)
        metrics['metric/note/precision'].append(p)
        metrics['metric/note/recall'].append(r)
        metrics['metric/note/f1'].append(f)
        metrics['metric/note/overlap'].append(o)

        p, r, f, o = evaluate_notes(i_ref, p_ref, i_est, p_est)
        metrics['metric/note-with-offsets/precision'].append(p)
        metrics['metric/note-with-offsets/recall'].append(r)
        metrics['metric/note-with-offsets/f1'].append(f)
        metrics['metric/note-with-offsets/overlap'].append(o)

    return metrics

def framewise_eval(pred, label, threshold=0.5):
    '''Evaluates frame-wise (point-wise) evaluation.

    Args:
        pred: torch.Tensor of shape (frame, pitch)
        label: torch.Tensor of shape (frame, pitch)
    '''

    tp = torch.sum((pred >= threshold) * (label == 1)).cpu().numpy()
    fn = torch.sum((pred < threshold) * (label == 1)).cpu().numpy()
    fp = torch.sum((pred >= threshold) * (label != 1)).cpu().numpy()

    pr = tp / float(tp + fp) if (tp + fp) > 0 else 0
    re = tp / float(tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * pr * re / float(pr + re) if (pr + re) > 0 else 0

    return pr, re, f1


def extract_notes(onsets, frames, onset_threshold=0.5, frame_threshold=0.5):
    """Finds the note timings based on the onsets and frames information.

    Args:
        onsets: torch.FloatTensor of shape (frames, bins)
        frames: torch.FloatTensor of shape (frames, bins)
        onset_threshold: float
        frame_threshold: float

    Returns:
        pitches: np.ndarray of bin_indices
        intervals: np.ndarray of rows containing (onset_index, offset_index)
    """
    onsets = (onsets > onset_threshold).type(torch.int).cpu()
    frames = (frames > frame_threshold).type(torch.int).cpu()
    onset_diff = torch.cat([onsets[:1, :], onsets[1:, :] - onsets[:-1, :]],
                           dim=0) == 1

    pitches = []
    intervals = []

    for nonzero in onset_diff.nonzero():
        frame = nonzero[0].item()
        pitch = nonzero[1].item()

        onset = frame
        offset = frame

        while onsets[offset, pitch].item() or frames[offset, pitch].item():
            offset += 1
            if offset == onsets.shape[0]:
                break
            if (offset != onset) and onsets[offset, pitch].item():
                break

        if offset > onset:
            pitches.append(pitch)
            intervals.append([onset, offset])

    return np.array(pitches), np.array(intervals)

# %% [markdown]
# ## Train and Validate the Model
#
# This cell in the main part to train and validate the model using data loaders and an optimizer.

# %%
class Runner(object):
    def __init__(self, model, lr, weight_decay):
      self.optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
      self.scheduler = StepLR(self.optimizer, step_size=1000, gamma=0.98)
      self.learning_rate = lr
      self.device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
      self.model = model.to(self.device)
      self.criterion = nn.BCELoss().to(self.device)
      self.iteration = 1000

    def train(self, dataloader):

      loop = tqdm(range(1, self.iteration + 1))

      for step, batch in zip(loop, cycle(dataloader)):
        self.optimizer.zero_grad()
        batch = allocate_batch(batch, self.device)

        frame_pred, onset_pred = self.model(batch['audio'])
        frame_loss = self.criterion(frame_pred, batch['frame'])
        onset_loss = self.criterion(onset_pred, batch['onset'])
        loss = onset_loss + frame_loss

        loss.mean().backward()

        for parameter in self.model.parameters():
            clip_grad_norm_([parameter], 3.0)

        self.optimizer.step()
        self.scheduler.step()
        loop.set_postfix_str("loss: {:.3e}".format(loss.mean()))

      return loss.mean()

    def test(self, dataloader):
      self.model.eval()
      with torch.no_grad():
        metrics = defaultdict(list)
        for batch in dataloader:
          batch_results = evaluate(model, batch, self.device)

          for key, value in batch_results.items():
            metrics[key].extend(value)

      for key, value in metrics.items():
        if key[-2:] == 'f1' in key:
          print(f'{key:27} : {np.mean(value):.4f}')

      self.model.train()
      valid_loss = np.mean(metrics['metric/loss/frame_loss']+metrics['metric/loss/onset_loss'])
      return valid_loss, batch_results

# %% [markdown]
# Let's start training the model!

# %%
z

# %%
learning_rate=1e-3

batch_size = 16

iterations=3000
validation_interval=1000
sequence_length=102400
# weight_decay=0.001
weight_decay=0
cnn_unit=24
fc_unit=64
rnn_unit=64

NUM_EPOCHS = 10

train_dataset = MAESTRO_small(groups=['train'], sequence_length=sequence_length, hop_size=HOP_SIZE, random_sample=True)
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)

valid_dataset = MAESTRO_small(groups=['validation'], sequence_length=sequence_length, hop_size=HOP_SIZE, random_sample=False)
valid_loader = DataLoader(valid_dataset, batch_size, shuffle=False)

model = BasicOnsetsAndFrames(cnn_unit=cnn_unit, fc_unit=fc_unit)
#model = OnsetsAndFrames(cnn_unit=cnn_unit, fc_unit=fc_unit, rnn_unit=rnn_unit)

runner = Runner(model=model, lr = learning_rate, weight_decay = weight_decay)

for epoch in range(NUM_EPOCHS):
  print("[Epoch %d/%d]" % (epoch + 1, NUM_EPOCHS))
  train_loss = runner.train(train_loader)
  valid_loss, result = runner.test(valid_loader)
# Out:
# Loading 1 group(s) of MAESTRO_small at gct634-maestro
# Loading group train:  78%|███████▊  | 78/100 [00:19<00:05,  3.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1302878/1322671602.py in <cell line: 16>()
#      14 NUM_EPOCHS = 10
#      15
# ---> 16 train_dataset = MAESTRO_small(groups=['train'], sequence_length=sequence_length, hop_size=HOP_SIZE, random_sample=True)
#      17 train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
#      18
#
# /tmp/ipykernel_1302878/116776735.py in __init__(self, path, groups, sequence_length, hop_size, seed, random_sample)
#      53             file_list:List[tuple] = self.get_file_path_list_of_group(group)
#      54             for input_files in tqdm(file_list, desc=f'Loading group {group}'):
# ---> 55                 self.data.append(self.load(*input_files))
#      56
#      57     @classmethod
#
# /tmp/ipykernel_1302878/116776735.py in load(self, audio_path, midi_path)
#      79     def load(self, audio_path:str, midi_path:str) -> Dict[str,Tensor]:
#      80         """Loads an audio track and the corresponding labels."""
# ---> 81         audio, sr = soundfile.read(audio_path, dtype='int16')
#      82         assert sr == SAMPLE_RATE
#      83
#
# ~/anaconda3/envs/gct634/lib/python3.9/site-packages/soundfile.py in read(file, frames, start, stop, dtype, always_2d, fill_value, out, samplerate, channels, format, subtype, endian, closefd)
#     306                    subtype, endian, format, closefd) as f:
#     307         frames = f._prepare_read(start, stop, frames)
# --> 308         data = f.read(frames, dtype, always_2d, fill_value, out)
#     309     return data, f.samplerate
#     310
#
# ~/anaconda3/envs/gct634/lib/python3.9/site-packages/soundfile.py in read(self, frames, dtype, always_2d, fill_value, out)
#     940             if frames < 0 or frames > len(out):
#     941                 frames = len(out)
# --> 942         frames = self._array_io('read', out, frames)
#     943         if len(out) > frames:
#     944             if fill_value is None:
#
# ~/anaconda3/envs/gct634/lib/python3.9/site-packages/soundfile.py in _array_io(self, action, array, frames)
#    1392         assert array.dtype.itemsize == _ffi.sizeof(ctype)
#    1393         cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1394         return self._cdata_io(action, cdata, ctype, frames)
#    1395
#    1396     def _cdata_io(self, action, data, ctype, frames):
#
# ~/anaconda3/envs/gct634/lib/python3.9/site-packages/soundfile.py in _cdata_io(self, action, data, ctype, frames)
#    1401             curr = self.tell()
#    1402         func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1403         frames = func(self._file, data, frames)
#    1404         _error_check(self._errorcode)
#    1405         if self.seekable():
#
# KeyboardInterrupt:

# %% [markdown]
# ## Transcribe a piece of piano recording
#
# Let's transcribe a piano music piece using the trained model.

# %%
import math
import torch.nn.functional as F
from mir_eval.util import midi_to_hz


def save_midi(path, pitches, intervals, velocities):
    """Saves extracted notes as a MIDI file.

    Args:
        path: the path to save the MIDI file
        pitches: np.ndarray of bin_indices
        intervals: list of tuple (onset_index, offset_index)
        velocities: list of velocity values
    """
    file = MidiFile()
    track = MidiTrack()
    file.tracks.append(track)
    ticks_per_second = file.ticks_per_beat * 2.0

    events = []
    for i in range(len(pitches)):
        events.append(
            dict(type='on',
                 pitch=pitches[i],
                 time=intervals[i][0],
                 velocity=velocities[i]))
        events.append(
            dict(type='off',
                 pitch=pitches[i],
                 time=intervals[i][1],
                 velocity=velocities[i]))
    events.sort(key=lambda row: row['time'])

    last_tick = 0
    for event in events:
        current_tick = int(event['time'] * ticks_per_second)
        velocity = int(event['velocity'] * 127)
        if velocity > 127:
            velocity = 127
        pitch = int(round(hz_to_midi(event['pitch'])))
        track.append(
            Message('note_' + event['type'],
                    note=pitch,
                    velocity=velocity,
                    time=current_tick - last_tick))
        last_tick = current_tick

    file.save(path)


# We use the example piano piece at the beginning.
audio_file = 'gct634-maestro/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.flac'
audio, sr = soundfile.read(audio_file)
audio_seg = audio[:10*sr]

t_audio = torch.tensor(audio_seg).to(torch.float).cuda()
pad_len = math.ceil(len(t_audio) / HOP_SIZE) * HOP_SIZE - len(t_audio)
t_audio = torch.unsqueeze(F.pad(t_audio, (0, pad_len)), 0)

frame_pred, onset_pred = model(t_audio)
p_est, i_est = extract_notes(onset_pred[0], frame_pred[0])

scaling = HOP_SIZE / SAMPLE_RATE
i_est = (i_est * scaling).reshape(-1, 2)
p_est = np.array([midi_to_hz(MIN_MIDI + pitch) for pitch in p_est])

midi_output_filename = 'output.midi'

save_midi(midi_output_filename, p_est, i_est, [64] * len(p_est))
midi_file = pretty_midi.PrettyMIDI(str(midi_output_filename))
synth_audio = midi_file.fluidsynth(fs=16000)


midi_score = libfmp.c1.midi_to_list(midi_output_filename)
libfmp.c1.visualize_piano_roll(midi_score, figsize=(8, 3))

ipd.Audio(synth_audio, rate=16000)

# %% [markdown]
# # Credit
# This homework was implemented and improved by Taegyun Kwon and Juhan Nam from the KAIST Music and Audio Computing Lab.
